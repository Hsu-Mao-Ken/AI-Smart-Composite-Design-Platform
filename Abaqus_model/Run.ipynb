# %%
import os
model_name = 'CEL-400_T300'
os.chdir(r'D:/TexGendata/woven_data_regular_angle_1/'+'Plastic_'+model_name)

# %%
for i in range(1,11):
    c = i*5
    print(f'{i}, {c}')
    #print(format(c,'2.3f'),'aafsdfsdfsdf\t', 'ffsd',sep='_')
# Out:
# 1, 5
# 2, 10
# 3, 15
# 4, 20
# 5, 25
# 6, 30
# 7, 35
# 8, 40
# 9, 45
# 10, 50

# %%
for step in range(401, 501):
    angle = 15*((step-1)//100)
    name = 'Plastic_'+model_name+'_'+str(angle)+'_'+str(step)
    run = 'abaqus job='+str(name)+' ask cpus=8 int'
    os.system(run)
    print(run)
# Out:
# abaqus job=Plastic_CEL-400_T300_60_401 ask cpus=8 int
# abaqus job=Plastic_CEL-400_T300_60_402 ask cpus=8 int
# abaqus job=Plastic_CEL-400_T300_60_403 ask cpus=8 int
# abaqus job=Plastic_CEL-400_T300_60_404 ask cpus=8 int
# abaqus job=Plastic_CEL-400_T300_60_405 ask cpus=8 int
# abaqus job=Plastic_CEL-400_T300_60_406 ask cpus=8 int
# abaqus job=Plastic_CEL-400_T300_60_407 ask cpus=8 int
# abaqus job=Plastic_CEL-400_T300_60_408 ask cpus=8 int
# abaqus job=Plastic_CEL-400_T300_60_409 ask cpus=8 int
# abaqus job=Plastic_CEL-400_T300_60_410 ask cpus=8 int
# abaqus job=Plastic_CEL-400_T300_60_411 ask cpus=8 int
# abaqus job=Plastic_CEL-400_T300_60_412 ask cpus=8 int
# abaqus job=Plastic_CEL-400_T300_60_413 ask cpus=8 int
# abaqus job=Plastic_CEL-400_T300_60_414 ask cpus=8 int
# abaqus job=Plastic_CEL-400_T300_60_415 ask cpus=8 int
# abaqus job=Plastic_CEL-400_T300_60_416 ask cpus=8 int
# abaqus job=Plastic_CEL-400_T300_60_417 ask cpus=8 int
# ...
