# %%
import os
model_name = 'ELER-8-130_T300_'
os.chdir(r'D:/TexGendata/woven_data_regular_angle_1/'+model_name+'angle')

# %%
for step in range(250, 501):
    a = (step-1)//100
    rotation = a*15
    name = model_name+str(rotation)+'_'+str(step)
    run = 'abaqus job='+str(name)+' ask cpus=6 int'
    os.system(run)
    print(run)
# Out:
# abaqus job=ELER-8-130_T300_30_250 ask cpus=6 int
# abaqus job=ELER-8-130_T300_30_251 ask cpus=6 int
# abaqus job=ELER-8-130_T300_30_252 ask cpus=6 int
# abaqus job=ELER-8-130_T300_30_253 ask cpus=6 int
# abaqus job=ELER-8-130_T300_30_254 ask cpus=6 int
# abaqus job=ELER-8-130_T300_30_255 ask cpus=6 int
# abaqus job=ELER-8-130_T300_30_256 ask cpus=6 int
# abaqus job=ELER-8-130_T300_30_257 ask cpus=6 int
# abaqus job=ELER-8-130_T300_30_258 ask cpus=6 int
# abaqus job=ELER-8-130_T300_30_259 ask cpus=6 int
# abaqus job=ELER-8-130_T300_30_260 ask cpus=6 int
# abaqus job=ELER-8-130_T300_30_261 ask cpus=6 int
# abaqus job=ELER-8-130_T300_30_262 ask cpus=6 int
# abaqus job=ELER-8-130_T300_30_263 ask cpus=6 int
# abaqus job=ELER-8-130_T300_30_264 ask cpus=6 int
# abaqus job=ELER-8-130_T300_30_265 ask cpus=6 int
# abaqus job=ELER-8-130_T300_30_266 ask cpus=6 int
# abaqus job=ELER-8-130_T300_30_267 ask cpus=6 int
# abaqus job=ELER-8-130_T300_30_268 ask cpus=6 int
# ...
